# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import logging

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from scripts.eda import CustomerBehaviorEDA

# %%
eda = CustomerBehaviorEDA(cleaned_data_path="../data/cleaned_data.csv")

# %%
eda.load_cleaned_data()
# Out:
# /home/hunegna/10x/10x_projects/rossman-sales-forecast/scripts/eda.py:30: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.cleaned_data_path)

# %%
eda.analyze_distributions()

# %%
eda.analyze_correlation()
# Out:
# Analyzing correlation matrix...
